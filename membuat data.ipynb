# %%
import os

# Data yang akan ditulis ke file CSV
data_csv = """nama_mahasiswa,nilai_tugas,nilai_kuis,nilai_uts
Bella Fauzi,66,100,94
Pratama Hakim,67,88,99
Xavier Fatimah,94,74,81
Rizky Rahman,73,60,86
Indah Ramadhan,76,84,94
Joko Maulana,95,66,60
Chandra Yudha,99,68,94
Yuni Wulandari,63,83,96
Maya Setyawan,61,60,73
Ahmad Fitri,65,67,62
Elisa Melati,63,83,60
Qori Sari,88,70,64
Fikri Prasetyo,77,76,85
Naufal Putra,85,67,73
Lukman Lestari,93,94,98
Wulan Anjani,69,94,86
Bunga Permata,95,92,68
Citra Paramita,73,64,74
Zahra Prakasa,90,98,74
Dimas Santoso,74,100,85
Vito Dewi,67,87,72
Aditya Kurniawan,73,66,91
Sari Hadi,82,68,98
Dewi Puspita,99,67,91
Umi Aulia,80,71,63
Hendra Wijaya,75,93,89
Kartika Nugroho,77,92,96
Olivia Jaya,83,82,82
Tegar Cahya,85,83,98
Gita Susilo,84,96,74
"""
# Tulis data ke file
nama_file = 'nilai_mahasiswa.csv'
with open(nama_file, 'w') as file:
    file.write(data_csv)

print(f"File '{nama_file}' berhasil dibuat.")
# Out:
# File 'nilai_mahasiswa.csv' berhasil dibuat.
